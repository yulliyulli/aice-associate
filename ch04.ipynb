# %% [markdown]
# # CH04. 기초 데이터 다루기

# %% [markdown]
# ## SECTION 01. 필요 데이터 선택하기

# %% [markdown]
# 컬럼명으로 데이터 선택하기

# %%
import pandas as pd
flight = pd.read_csv('./dataset/Clean_Dataset.csv')

# %%
flight[['departure_time']]  # 컬럼 1개
# Out:
#        departure_time
# 0             Evening
# 1       Early_Morning
# 2       Early_Morning
# 3             Morning
# 4             Morning
# ...               ...
# 300148        Morning
# 300149      Afternoon
# 300150  Early_Morning
# 300151  Early_Morning
# 300152        Morning
#
# [300153 rows x 1 columns]

# %%
flight[['departure_time', 'airline']] # 여러개의 컬럼
# Out:
#        departure_time   airline
# 0             Evening  SpiceJet
# 1       Early_Morning  SpiceJet
# 2       Early_Morning   AirAsia
# 3             Morning   Vistara
# 4             Morning   Vistara
# ...               ...       ...
# 300148        Morning   Vistara
# 300149      Afternoon   Vistara
# 300150  Early_Morning   Vistara
# 300151  Early_Morning   Vistara
# 300152        Morning   Vistara
#
# [300153 rows x 2 columns]

# %% [markdown]
# 행 범위를 지정하여 데이터 선택하기 : 슬라이싱

# %%
flight[10:21]
# Out:
#     Unnamed: 0    airline   flight source_city departure_time stops  \
# 10          10   GO_FIRST   G8-392       Delhi      Afternoon  zero
# 11          11   GO_FIRST   G8-338       Delhi        Morning  zero
# 12          12     Indigo  6E-5001       Delhi  Early_Morning  zero
# 13          13     Indigo  6E-6202       Delhi        Morning  zero
# 14          14     Indigo   6E-549       Delhi      Afternoon  zero
# 15          15     Indigo  6E-6278       Delhi        Morning  zero
# 16          16  Air_India   AI-887       Delhi  Early_Morning  zero
# 17          17  Air_India   AI-665       Delhi  Early_Morning  zero
# 18          18    AirAsia   I5-747       Delhi        Evening   one
# 19          19    AirAsia   I5-747       Delhi        Evening   one
# 20          20   GO_FIRST   G8-266       Delhi  Early_Morning   one
#
#      arrival_time destination_city    class  duration  days_left  price
# 10        Evening           Mumbai  Economy      2.25          1   5954
# ...

# %% [markdown]
# 특정 행, 열의 범위를 선택
# - `loc(location)`
#     - 설정한 인덱스를 그대로 사용
#     - 행과 열에 레이블로 접근
# - `iloc(integer location)`
#     - 0 based index 사용
#     - 행과 열에 index로 접근

# %%
flight.loc[[100,101]]
# Out:
#      Unnamed: 0   airline  flight source_city departure_time stops  \
# 100         100   Vistara  UK-705       Delhi  Early_Morning   one
# 101         101  GO_FIRST  G8-191       Delhi        Morning   one
#
#     arrival_time destination_city    class  duration  days_left  price
# 100        Night           Mumbai  Economy     12.83          1  18450
# 101      Evening           Mumbai  Economy      8.92          1  18487

# %%
flight.loc[[101,101], ['airline']]
# Out:
#       airline
# 101  GO_FIRST
# 101  GO_FIRST

# %%
flight.iloc[[2,102,202]]
# Out:
#      Unnamed: 0  airline  flight source_city departure_time stops  \
# 2             2  AirAsia  I5-764       Delhi  Early_Morning  zero
# 102         102  Vistara  UK-819       Delhi      Afternoon   one
# 202         202  Vistara  UK-879       Delhi        Evening   one
#
#       arrival_time destination_city    class  duration  days_left  price
# 2    Early_Morning           Mumbai  Economy      2.17          1   5956
# 102          Night           Mumbai  Economy      6.00          1  18923
# 202          Night           Mumbai  Economy      5.33          2  13673

# %%
flight.iloc[[2,102,202], [1,2,3]]
# Out:
#      airline  flight source_city
# 2    AirAsia  I5-764       Delhi
# 102  Vistara  UK-819       Delhi
# 202  Vistara  UK-879       Delhi

# %% [markdown]
# 조건으로 데이터 선택

# %%
flight_extract = flight[(flight['price']>12000)&(flight['airline']=='Air_India')]

# %%
flight_extract
# Out:
#         Unnamed: 0    airline  flight source_city departure_time stops  \
# 40              40  Air_India  AI-504       Delhi          Night   one
# 41              41  Air_India  AI-502       Delhi      Afternoon   one
# 42              42  Air_India  AI-506       Delhi        Morning   one
# 43              43  Air_India  AI-803       Delhi  Early_Morning   one
# 44              44  Air_India  AI-479       Delhi          Night   one
# ...            ...        ...     ...         ...            ...   ...
# 300143      300143  Air_India  AI-440     Chennai  Early_Morning   one
# 300144      300144  Air_India  AI-539     Chennai        Evening   one
# 300145      300145  Air_India  AI-430     Chennai        Morning   one
# 300146      300146  Air_India  AI-440     Chennai  Early_Morning   one
# 300147      300147  Air_India  AI-569     Chennai  Early_Morning   one
#
#        arrival_time destination_city     class  duration  days_left  price
# ...

# %%
price_tag = (flight['price']>12000)
airline_tag = (flight['airline']=='Air_India')
flight_extract2 = flight[price_tag & airline_tag]

# %%
flight_extract2
# Out:
#         Unnamed: 0    airline  flight source_city departure_time stops  \
# 40              40  Air_India  AI-504       Delhi          Night   one
# 41              41  Air_India  AI-502       Delhi      Afternoon   one
# 42              42  Air_India  AI-506       Delhi        Morning   one
# 43              43  Air_India  AI-803       Delhi  Early_Morning   one
# 44              44  Air_India  AI-479       Delhi          Night   one
# ...            ...        ...     ...         ...            ...   ...
# 300143      300143  Air_India  AI-440     Chennai  Early_Morning   one
# 300144      300144  Air_India  AI-539     Chennai        Evening   one
# 300145      300145  Air_India  AI-430     Chennai        Morning   one
# 300146      300146  Air_India  AI-440     Chennai  Early_Morning   one
# 300147      300147  Air_India  AI-569     Chennai  Early_Morning   one
#
#        arrival_time destination_city     class  duration  days_left  price
# ...

# %% [markdown]
# ## SECTION 02. 필요 데이터 변경하기

# %% [markdown]
# 데이터 추가하기 `insert`
# - df.insert(loc, column, value, allow_duplicates)
#     - allow_duplicates : 기본값 false, 중복값 삽입을 허용하지 않음

# %%
flight['price2'] = flight['price'] *2

# %%
flight[['price', 'price2']].head()
# Out:
#    price  price2
# 0   5953   11906
# 1   5953   11906
# 2   5956   11912
# 3   5955   11910
# 4   5955   11910

# %%
flight.insert(10, 'duration2', flight['duration']*2) # 10: 위치 지정도 가능

# %%
flight.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  duration2  days_left  \
# 0          Night           Mumbai  Economy      2.17       4.34          1
# 1        Morning           Mumbai  Economy      2.33       4.66          1
# 2  Early_Morning           Mumbai  Economy      2.17       4.34          1
# 3      Afternoon           Mumbai  Economy      2.25       4.50          1
# 4        Morning           Mumbai  Economy      2.33       4.66          1
#
#    price  price2
# 0   5953   11906
# 1   5953   11906
# 2   5956   11912
# 3   5955   11910
# 4   5955   11910

# %% [markdown]
# 데이터 삭제하기 `drop`
# - `axis=1` : 열 레벨로 데이터를 삭제
# - `axis=0` : 행 레벨로 데이터를 삭제

# %%
flight.drop('price2', axis=1) #열 삭제
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  duration2  \
# ...

# %%
flight.drop(index=0, axis=0) # 행 삭제
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# 5                5   Vistara   UK-945       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  duration2  \
# ...

# %%
flight.head() # 위와 같이 drop 하면 원본 데이터 프레임에 반영되지 않음
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  duration2  days_left  \
# 0          Night           Mumbai  Economy      2.17       4.34          1
# 1        Morning           Mumbai  Economy      2.33       4.66          1
# 2  Early_Morning           Mumbai  Economy      2.17       4.34          1
# 3      Afternoon           Mumbai  Economy      2.25       4.50          1
# 4        Morning           Mumbai  Economy      2.33       4.66          1
#
#    price  price2
# 0   5953   11906
# 1   5953   11906
# 2   5956   11912
# 3   5955   11910
# 4   5955   11910

# %%
flight = flight.drop('price2', axis=1) #열 삭제

# %%
flight = flight.drop(index=0, axis=0) # 행 삭제

# %%
flight.head() # 삭제 확인
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
# 5           5   Vistara   UK-945       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  duration2  days_left  \
# 1        Morning           Mumbai  Economy      2.33       4.66          1
# 2  Early_Morning           Mumbai  Economy      2.17       4.34          1
# 3      Afternoon           Mumbai  Economy      2.25       4.50          1
# 4        Morning           Mumbai  Economy      2.33       4.66          1
# 5      Afternoon           Mumbai  Economy      2.33       4.66          1
#
#    price
# 1   5953
# 2   5956
# 3   5955
# 4   5955
# 5   5955

# %%
flight.drop(index=1, axis=0, inplace=True) #inplace=True 데이터 프레임에 반영

# %%
flight
# Out:
#         Unnamed: 0  airline  flight source_city departure_time stops  \
# 2                2  AirAsia  I5-764       Delhi  Early_Morning  zero
# 3                3  Vistara  UK-995       Delhi        Morning  zero
# 4                4  Vistara  UK-963       Delhi        Morning  zero
# 5                5  Vistara  UK-945       Delhi        Morning  zero
# 6                6  Vistara  UK-927       Delhi        Morning  zero
# ...            ...      ...     ...         ...            ...   ...
# 300148      300148  Vistara  UK-822     Chennai        Morning   one
# 300149      300149  Vistara  UK-826     Chennai      Afternoon   one
# 300150      300150  Vistara  UK-832     Chennai  Early_Morning   one
# 300151      300151  Vistara  UK-828     Chennai  Early_Morning   one
# 300152      300152  Vistara  UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  duration2  \
# ...

# %% [markdown]
# 컬럼명 변경하기 `rename`

# %%
flight = flight.rename(columns={"airline":"airline_name"})

# %%
flight.head()
# Out:
#    Unnamed: 0 airline_name  flight source_city departure_time stops  \
# 2           2      AirAsia  I5-764       Delhi  Early_Morning  zero
# 3           3      Vistara  UK-995       Delhi        Morning  zero
# 4           4      Vistara  UK-963       Delhi        Morning  zero
# 5           5      Vistara  UK-945       Delhi        Morning  zero
# 6           6      Vistara  UK-927       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  duration2  days_left  \
# 2  Early_Morning           Mumbai  Economy      2.17       4.34          1
# 3      Afternoon           Mumbai  Economy      2.25       4.50          1
# 4        Morning           Mumbai  Economy      2.33       4.66          1
# 5      Afternoon           Mumbai  Economy      2.33       4.66          1
# 6        Morning           Mumbai  Economy      2.08       4.16          1
#
#    price
# 2   5956
# 3   5955
# 4   5955
# 5   5955
# 6   6060

# %% [markdown]
# 데이터프레임 정렬하기 `sort_values`

# %%
flight = flight.sort_values(by='Unnamed: 0', ascending=False)

# %%
flight
# Out:
#         Unnamed: 0 airline_name  flight source_city departure_time stops  \
# 300152      300152      Vistara  UK-822     Chennai        Morning   one
# 300151      300151      Vistara  UK-828     Chennai  Early_Morning   one
# 300150      300150      Vistara  UK-832     Chennai  Early_Morning   one
# 300149      300149      Vistara  UK-826     Chennai      Afternoon   one
# 300148      300148      Vistara  UK-822     Chennai        Morning   one
# ...            ...          ...     ...         ...            ...   ...
# 6                6      Vistara  UK-927       Delhi        Morning  zero
# 5                5      Vistara  UK-945       Delhi        Morning  zero
# 4                4      Vistara  UK-963       Delhi        Morning  zero
# 3                3      Vistara  UK-995       Delhi        Morning  zero
# 2                2      AirAsia  I5-764       Delhi  Early_Morning  zero
#
#          arrival_time destination_city     class  duration  duration2  \
# ...

# %% [markdown]
# ## SECTION 03. 데이터프레임 변형하기

# %% [markdown]
# 그룹화 하기 `groupby`
# - 제공 정보
#     - count: 데이터 개수, size: 집단별 크기, sum: 데이터의 합, mean,std,var: 평균,표준편차,분산, min-max: 최솟값-최댓값

# %%
import pandas as pd
flight = pd.read_csv('./dataset/Clean_Dataset.csv')

# %%
airline_group = flight.groupby('airline')
airline_group # 데이터 프레임으로 그룹까지 생성

# %%
airline_group.groups # 그룹화된 결과 확인
# Out:
# {'AirAsia': [2, 18, 19, 27, 48, 141, 147, 148, 157, 265, 290, 325, 435, 450, 608, 609, 623, 706, 746, 782, 783, 784, 814, 978, 993, 1085, 1088, 1133, 1210, 1248, 1261, 1284, 1323, 1341, 1343, 1461, 1466, 1483, 1526, 1583, 1685, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1728, 1759, 1760, 1761, 1762, 1866, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1947, 1972, 1974, 1976, 1977, 1991, 1992, 2083, 2127, 2128, 2129, 2130, 2131, 2132, 2133, 2134, 2135, 2167, 2194, 2196, 2264, 2265, 2292, 2305, 2350, 2351, 2352, 2353, 2354, 2355, 2397, 2422, 2423, 2443, 2444, 2465, 2484, ...], 'Air_India': [16, 17, 23, 37, 40, 41, 42, 43, 44, 49, 50, 51, 52, 53, 60, 71, 74, 75, 82, 86, 87, 96, 98, 107, 108, 110, 113, 114, 115, 117, 142, 143, 144, 145, 146, 151, 152, 162, 163, 164, 166, 168, 173, 182, 189, 191, 193, 195, 196, 197, 198, 199, 207, 211, 223, 225, 229, 236, 237, 241, 242, 243, 247, 250, 266, 267, 268, 269, 272, 280, 291, 295, 303, 309, 314, 315, 316, 319, 321, 329, 333, 343, 352, 357,
# ...

# %%
airline_group.count() # 데이터 개수 확인
# Out:
#            Unnamed: 0  flight  source_city  departure_time   stops  \
# airline
# AirAsia         16098   16098        16098           16098   16098
# Air_India       80892   80892        80892           80892   80892
# GO_FIRST        23173   23173        23173           23173   23173
# Indigo          43120   43120        43120           43120   43120
# SpiceJet         9011    9011         9011            9011    9011
# Vistara        127859  127859       127859          127859  127859
#
#            arrival_time  destination_city   class  duration  days_left   price
# airline
# AirAsia           16098             16098   16098     16098      16098   16098
# Air_India         80892             80892   80892     80892      80892   80892
# GO_FIRST          23173             23173   23173     23173      23173   23173
# Indigo            43120             43120   43120     43120      43120   43120
# SpiceJet           9011              9011    9011      9011       9011    9011
# ...

# %% [markdown]
# 인덱스로 그룹화하기
# - `set_index` 컬럼을 인덱스로 변경, 기존의 인덱스를 제거하고 컬럼 중 하나를 인덱스로 설정
# - `reset_index` 인덱스 초기화

# %%
flight.set_index(['airline', 'arrival_time']) # index 를 설정한 결과, 그룹핑은 안된 상태
# Out:
#                         Unnamed: 0   flight source_city departure_time stops  \
# airline  arrival_time
# SpiceJet Night                   0  SG-8709       Delhi        Evening  zero
#          Morning                 1  SG-8157       Delhi  Early_Morning  zero
# AirAsia  Early_Morning           2   I5-764       Delhi  Early_Morning  zero
# Vistara  Afternoon               3   UK-995       Delhi        Morning  zero
#          Morning                 4   UK-963       Delhi        Morning  zero
# ...                            ...      ...         ...            ...   ...
#          Evening            300148   UK-822     Chennai        Morning   one
#          Night              300149   UK-826     Chennai      Afternoon   one
#          Night              300150   UK-832     Chennai  Early_Morning   one
#          Evening            300151   UK-828     Chennai  Early_Morning   one
#          Evening            300152   UK-822     Chennai        Morning   one
#
# ...

# %%
# level(depth)으로 0으로 설정한 인덱스 중 airline을 기준으로 그룹화
flight.set_index(['airline', 'arrival_time']).groupby(level=[0]).min()
# Out:
#            Unnamed: 0   flight source_city departure_time stops  \
# airline
# AirAsia             2  I5-1228   Bangalore      Afternoon   one
# Air_India          16   AI-401   Bangalore      Afternoon   one
# GO_FIRST            8   G8-101   Bangalore      Afternoon   one
# Indigo             12   6E-102   Bangalore      Afternoon   one
# SpiceJet            0  SG-1031   Bangalore      Afternoon   one
# Vistara             3   UK-613   Bangalore      Afternoon   one
#
#           destination_city     class  duration  days_left  price
# airline
# AirAsia          Bangalore   Economy      0.92          1   1105
# Air_India        Bangalore  Business      1.00          1   1526
# GO_FIRST         Bangalore   Economy      1.00          1   1105
# Indigo           Bangalore   Economy      0.83          1   1105
# SpiceJet         Bangalore   Economy      1.00          1   1106
# Vistara          Bangalore  Business      1.00          1   1714

# %%
# level(depth)으로 airline, arrival_time을 기준으로 그룹화
flight.set_index(['airline', 'arrival_time']).groupby(level=[0,1]).min()
# Out:
#                          Unnamed: 0   flight source_city departure_time stops  \
# airline   arrival_time
# AirAsia   Afternoon              27  I5-1228   Bangalore      Afternoon   one
#           Early_Morning           2  I5-1229   Bangalore  Early_Morning   one
#           Evening             10006  I5-1228   Bangalore      Afternoon   one
#           Late_Night           1693  I5-1228   Bangalore      Afternoon   one
#           Morning                19  I5-1228   Bangalore  Early_Morning   one
#           Night                1323  I5-1228   Bangalore      Afternoon   one
# Air_India Afternoon              37   AI-402   Bangalore      Afternoon   one
#           Early_Morning        8846   AI-403   Bangalore      Afternoon   one
#           Evening               110   AI-401   Bangalore      Afternoon   one
#           Late_Night            193   AI-401   Bangalore      Afternoon   one
#           Morning                16   AI-401   Bangalore      Afternoon   one
# ...

# %% [markdown]
# aggregate로 집계하기
# - 값을 다양하게 집계하여 한번에 볼 수 있음

# %%
import numpy as np
flight.set_index(['airline', 'arrival_time']).groupby(level=[0,1]).aggregate(['min', 'max'])
# Out:
#                         Unnamed: 0           flight          source_city  \
#                                min     max      min      max         min
# airline   arrival_time
# AirAsia   Afternoon             27  202598  I5-1228   I5-942   Bangalore
#           Early_Morning          2  193744  I5-1229   I5-996   Bangalore
#           Evening            10006  205846  I5-1228   I5-991   Bangalore
#           Late_Night          1693  202571  I5-1228   I5-992   Bangalore
#           Morning               19  206617  I5-1228   I5-992   Bangalore
#           Night               1323  202569  I5-1228   I5-996   Bangalore
# Air_India Afternoon             37  299989   AI-402  AI-9937   Bangalore
#           Early_Morning       8846  300114   AI-403  AI-9928   Bangalore
#           Evening              110  299935   AI-401  AI-9929   Bangalore
#           Late_Night           193  295659   AI-401  AI-9929   Bangalore
# ...

# %% [markdown]
# 피벗테이블 생성하기
# - `pivot` 값이 중복되는 경우 에러가 발생
#     - ValueError: Index contains duplicate entries, cannot reshape
# - `pivot_table` 값이 중복되는 경우 처리를 지정할 수 있는 `aggfunc` 매개변수를 제공

# %%
# 데이터프레임 생성
df = pd.DataFrame({
    'Date': ['2022-01-01', '2022-01-01', '2022-01-02', '2022-01-02'],
    'Category': ['A', 'B', 'A', 'B'],
    'Value': [10, 20, 30, 40]
})

df.pivot(index='Date', columns='Category', values='Value')
# Out:
# Category     A   B
# Date
# 2022-01-01  10  20
# 2022-01-02  30  40

# %%
# 피벗 테이블 생성
pivot_table = df.pivot_table(index='Date', columns='Category', values='Value', aggfunc='sum')
print(pivot_table)
# Out:
# Category     A   B
# Date
# 2022-01-01  10  20
# 2022-01-02  30  40

# %% [markdown]
# 인덱스 및 칼럼 레벨 변경하기
# - `stack`
#     - 칼럼 레벨에서 인덱스 레벨로 데이터 프레임을 변경
# - `unstack`
#     - 인덱스 레벨에서 칼럼 레벨로 위치를 변경

# %% [markdown]
# ## SECTION 04. 데이터프레임 병합하기

# %% [markdown]
# 2개 이상의 데이터 프레임을 병합 `concat`
# - 칼럼 명이 같은 경우
#     - `ignore_index` 기존 인덱스를 유지하거나 무시
#         - `False(default)` 기존 인덱스 유지
#         - `True` 기존 인덱스 무시(인덱스 재배열)
#     - `axis` 데이터프레임을 행 레벨로 병합할 것인지, 칼럼 레벨로 병합할 것인지 정의
#         - `axis=0(default)` 행 레벨로 병합(위+아래, 세로로 합치기)
#         - `axis=1` 칼럼 레벨로 병합(왼쪽+오른쪽, 가로로 합치기)
# - 칼럼 명이 다른 경우
#     - `join`
#         - `outer` 합집합
#         - `inner` 교집합
# - 인덱스가 중복인 경우
#     - `verify_integrity` 데이터프레임에서 인덱스의 중복 여부를 점검하는 파라미터
#         - `False(default)` 인덱스 중복으로 인한 에러가 발생하지 않음
#         - `True` 인덱스 중복으로 인한 에러 발생

# %% [markdown]
# 특정한 key 기준으로 데이터프레임 병합 `merge/join`
# - `merge` 서로 다른 형태와 값의 데이터프레임을 병합할 때 사용
#     - `on` 어떤 칼럼을 이용하여 merge 할 것인지 정의
#     - `how` merge 방식을 정의
#         - `inner(default)` 일치하는 값이 있는 경우에만 데이터를 가져옴.
#         - `left` 왼쪽 데이터프레임을 기준으로 오른쪽 데이터프레임을 병합
#         - `right` 오른쪽 데이터프레임을 기준으로 왼쪽 데이터프레임을 병합
#         - `outer` left 와 right를 합한 데이터프레임을 병합
